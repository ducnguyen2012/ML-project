# %% [markdown]
# ### import thư viện

# %%
from bs4 import BeautifulSoup
import requests
from time import sleep

# %% [markdown]
# ### Đọc file txt movie_link

# %%
#! lấy data đã được xử lý (lúc này phải chạy ipynb trong datapreprocessing) cho vào all_movie_link:
all_movie_link = []
with open('../DataPreprocessing/processed_movie_link.txt','r',encoding="utf8") as file:
    all_movie_link = file.readlines()
all_movie_link.pop(0)
# Out:
# 'https://myanimelist.net/anime/season?_location=mal_h_m\n'

# %%
all_movie_link[0]
# Out:
# 'https://myanimelist.net/anime/52991/Sousou_no_Frieren\n'

# %% [markdown]
# ### Lấy dữ liệu thông tin phim: gồm 27 trường chính và 5000 dòng

# %%
#! crawl thông tin phim
cnt = 0
# url = "https://myanimelist.net/anime/5114/Fullmetal_Alchemist__Brotherhood"
my_in4 = [] #! mỗi my_in4 chỉ chứa được 100 phần tử thông tin phim! 
for url in all_movie_link:
    cnt += 1
    
    page = requests.get(url)
    sleep(2)
    soup = BeautifulSoup(page.text,'html')


    path = soup.find_all(class_="spaceit_pad")
    sleep(2)
    # for i in path:
    #     print(i.get_text())
    temp = []
    for in4 in path:

        a = in4.get_text().replace('\n','')

        temp.append(a)
    my_in4.append(temp)
    # if cnt == 100:
    #     break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\response.py:761, in HTTPResponse._update_chunk_length(self)
#     760 try:
# --> 761     self.chunk_left = int(line, 16)
#     762 except ValueError:
#     763     # Invalid chunked protocol response, abort.
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\urllib3\response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# ...

# %%
len(my_in4)
# Out:
# 3048

# %%
#! viết thông tin vào file csv:

#! Nếu quá bí thì có thể thử trò chọn column luôn cho data. 
import pandas as pd

#! taojh dict để lưu key và value:
# my_dict = {}
attr = []
new_value = []
temp = []
temp0 = []
temp1 = []
temp2 = []
temp3 = []
temp4 = []
temp5 = []
temp6 = []
temp7 = []
temp8 = []
temp9 = []
temp10 = []
temp11 = []
temp12 = []
temp13 = []
temp14 = []
temp15 = []
temp16 = []
temp17 = []
temp18 = []
temp19 = []
temp20 = []
temp21 = []
temp22 = []
temp23 = []
temp24 = []
temp25 = []
temp26 = []
temp27 = []
attr0 = []
attr1 = []
attr2 = []
attr3 = []
attr4 = []
attr5 = []
attr6 = []
attr7 = []
attr8 = []
attr9 = []
attr10 = []
attr11 = []
attr12 = []
attr13 = []
attr14 = []
attr15 = []
attr16 = []
attr17 = []
attr18 = []
attr19 = []
attr20 = []
attr21 = []
attr22 = []
attr23 = []
attr24 = []
attr25 = []
attr26 = []
attr27 = [] 
    
for my_val in my_in4:
    for in4 in my_val:
        if ":" in in4:
            key = in4.index(":")
            in4_attr = in4[:key]
            value = in4[key+1:]
            attr.append(in4_attr)
            temp.append(value)
    temp = []
    new_value.append(temp)

new_attr = list(set(attr))
print(len(new_attr))
print(new_value)
for my_val in my_in4:
    for in4 in my_val:
        if new_attr[0] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp0.append(value)
        if new_attr[1] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp1.append(value)
        if new_attr[2] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp2.append(value)
        if new_attr[3] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp3.append(value)
        if new_attr[4] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp4.append(value)
        if new_attr[5] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp5.append(value)
        if new_attr[6] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp6.append(value)
        if new_attr[7] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp7.append(value)
        if new_attr[8] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp8.append(value)
        if new_attr[9] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp9.append(value)
        if new_attr[10] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp10.append(value)
        if new_attr[11] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp11.append(value)
        if new_attr[12] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp12.append(value)
        if new_attr[13] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp13.append(value)
        if new_attr[14] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp14.append(value)
        if new_attr[15] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp15.append(value)
        if new_attr[16] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp16.append(value)
        if new_attr[17] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp17.append(value)
        if new_attr[18] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp18.append(value)
        if new_attr[19] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp19.append(value)
        if new_attr[20] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp20.append(value)
        if new_attr[21] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp21.append(value)
        if new_attr[22] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp22.append(value)
        if new_attr[23] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp23.append(value)
        if new_attr[24] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp24.append(value)
        if new_attr[25] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp25.append(value)
        if new_attr[26] in in4: 
            if ":" in in4:
                key = in4.index(":")
                value = in4[key+1:]
                temp26.append(value)
    attr0.append(temp0)
    attr1.append(temp1)
    attr2.append(temp2)
    attr3.append(temp3)
    attr4.append(temp4)
    attr5.append(temp5)
    attr6.append(temp6)
    attr7.append(temp7)
    attr8.append(temp8)
    attr9.append(temp9)
    attr10.append(temp10)
    attr11.append(temp11)
    attr12.append(temp12)
    attr13.append(temp13)
    attr14.append(temp14)
    attr15.append(temp15)
    attr16.append(temp16)
    attr17.append(temp17)
    attr18.append(temp18)
    attr19.append(temp19)
    attr20.append(temp20)
    attr21.append(temp21)
    attr22.append(temp22)
    attr23.append(temp23)
    attr24.append(temp24)
    attr25.append(temp25)
    attr26.append(temp26)
    temp0 = []
    temp1 = []
    temp2 = []
    temp3 = []
    temp4 = []
    temp5 = []
    temp6 = []
    temp7 = []
    temp8 = []
    temp9 = []
    temp10 = []
    temp11 = []
    temp12 = []
    temp13 = []
    temp14 = []
    temp15 = []
    temp16 = []
    temp17 = []
    temp18 = []
    temp19 = []
    temp20 = []
    temp21 = []
    temp22 = []
    temp23 = []
    temp24 = []
    temp25 = []
    temp26 = []
    
df = pd.DataFrame({new_attr[0]: attr0, new_attr[1]: attr1,new_attr[2]: attr2, new_attr[3]: attr3, new_attr[4]: attr4,new_attr[5]: attr5, new_attr[6]: attr6,new_attr[7]: attr7, new_attr[8]: attr8, new_attr[9]: attr9,
        new_attr[10]: attr10, new_attr[11]: attr11,new_attr[12]: attr12, new_attr[13]: attr13, new_attr[14]: attr14,new_attr[15]: attr15, new_attr[16]: attr16,new_attr[17]: attr17, new_attr[18]: attr18, new_attr[19]: attr19,         
        new_attr[20]: attr20, new_attr[21]: attr21,new_attr[22]: attr22, new_attr[23]: attr23, new_attr[4]: attr24,new_attr[25]: attr25, new_attr[26]: attr26})
df.to_csv('./in4_movie_test2.csv')
# Out:
# 29
# ...

# %%
df = pd.read_csv('./in4_movie_test2.csv')
df.describe()
# Out:
#         Unnamed: 0
# count  3048.000000
# mean   1523.500000
# std     880.026136
# min       0.000000
# 25%     761.750000
# 50%    1523.500000
# 75%    2285.250000
# max    3047.000000

# %%
df.head(3)
# Out:
#    Unnamed: 0                           Japanese  \
# 0           0                    [' 葬送のフリーレン  ']
# 1           1  [' 鋼の錬金術師 FULLMETAL ALCHEMIST  ']
# 2           2                 [' STEINS;GATE  ']
#
#                                                Genre    Type        Premiered  \
# 0  ['AdventureAdventure,         DramaDrama,     ...  ['TV']    ['Fall 2023']
# 1  ['ActionAction,         AdventureAdventure,   ...  ['TV']  ['Spring 2009']
# 2  ['DramaDrama,         Sci-FiSci-Fi,         Su...  ['TV']  ['Spring 2011']
#
#                                         Source    Episodes  \
# 0     [" Frieren: Beyond Journey's End      "]  ['  28  ']
# 1  [' Fullmetal Alchemist: Brotherhood      ']  ['  64  ']
# 2                       [' Steins;Gate      ']  ['  24  ']
#
#                                                Score  \
# 0  ['9.371 (scored by 386509386,509 users)      1...
# 1  ['9.091 (scored by 21209322,120,932 users)    ...
# ...

# %% [markdown]
# ### xong việc lấy thông tin các phim

# %% [markdown]
# ### Crawl description

# %%
#! crawl comment and overview
#! vào từng đường link một để lấy toàn bộ thông tin về phim đó. Mình sẽ chỉ lấy 3 cmt đầu nhiều reaction nhất của bộ phim đó. 
#! check thử url: 
#! comment đã oke. Giờ thì còn overview phim

#! data sẽ kiểu: tên phim + description + tên tác giả
cnt = 0
my_description = []
movie_name = []
for url in all_movie_link:
    cnt += 1
#url = "https://myanimelist.net/anime/52991/Sousou_no_Frieren"
    page = requests.get(url)

    soup = BeautifulSoup(page.text,'html')
    path = soup.find_all(itemprop="description")

    
    for text in path:
    
        a = text.get_text().replace('\n','')
    
        my_description.append(a)
    path_name = soup.find_all(class_="title-name h1_bold_none")
    for name in path_name:
        temp = name.get_text().replace('\n','')
        movie_name.append(temp)
    if cnt == 5:
        break

# %%
my_description
# Out:
# ['During their decade-long quest to defeat the Demon King, the members of the hero\'s party—Himmel himself, the priest Heiter, the dwarf warrior Eisen, and the elven mage Frieren—forge bonds through adventures and battles, creating unforgettable precious memories for most of them.\rHowever, the time that Frieren spends with her comrades is equivalent to merely a fraction of her life, which has lasted over a thousand years. When the party disbands after their victory, Frieren casually returns to her "usual" routine of collecting spells across the continent. Due to her different sense of time, she seemingly holds no strong feelings toward the experiences she went through.\rAs the years pass, Frieren gradually realizes how her days in the hero\'s party truly impacted her. Witnessing the deaths of two of her former companions, Frieren begins to regret having taken their presence for granted; she vows to better understand humans and create real personal connections. Although the story of 
# ...

# %%
movie_name
# Out:
# ['Sousou no Frieren',
#  'Fullmetal Alchemist: Brotherhood',
#  'Steins;Gate',
#  'Gintama°']

# %%
my_description[0][:my_description[0].index('Written by')]
# Out:
# 'During their decade-long quest to defeat the Demon King, the members of the hero\'s party—Himmel himself, the priest Heiter, the dwarf warrior Eisen, and the elven mage Frieren—forge bonds through adventures and battles, creating unforgettable precious memories for most of them.\rHowever, the time that Frieren spends with her comrades is equivalent to merely a fraction of her life, which has lasted over a thousand years. When the party disbands after their victory, Frieren casually returns to her "usual" routine of collecting spells across the continent. Due to her different sense of time, she seemingly holds no strong feelings toward the experiences she went through.\rAs the years pass, Frieren gradually realizes how her days in the hero\'s party truly impacted her. Witnessing the deaths of two of her former companions, Frieren begins to regret having taken their presence for granted; she vows to better understand humans and create real personal connections. Although the story of t
# ...

# %%
author = []
description = []
for des in my_description:
    key = des.index('Written by')
    
    des_text = des[:key-1]
    
    des_author = des[key+11:-1]
    
    author.append(des_author)
    description.append(des_text)
author
# Out:
# ['MAL Rewrite', 'MAL Rewrite', 'MAL Rewrite', 'MAL Rewrite']

# %%
df_synonym = pd.DataFrame({'name': movie_name, 'description': description,'Author':author})
df_synonym
# Out:
#                                name  \
# 0                 Sousou no Frieren
# 1  Fullmetal Alchemist: Brotherhood
# 2                       Steins;Gate
# 3                          Gintama°
#
#                                          description       Author
# 0  During their decade-long quest to defeat the D...  MAL Rewrite
# 1  After a horrific alchemy experiment goes wrong...  MAL Rewrite
# 2  Eccentric scientist Rintarou Okabe has a never...  MAL Rewrite
# 3  Gintoki, Shinpachi, and Kagura return as the f...  MAL Rewrite

# %%
#! ghi description vao file csv
# my_dict = {}

# key = my_description[0].index('Written by')
# my_dict[in4[:key-3]] = in4[key+10:-1]
# df = pd.DataFrame({'description': my_dict.keys(), 'author': my_dict.values()})
# df.to_csv('./description_and_author.csv',index=False)


import pandas as pd

#! taojh dict để lưu key và value:
#my_dict = {}
attr = []
value = []
for in4 in my_description:
    key = in4.index('Written by')
    in4_att = in4[:key]
    in4_val = in4[key+11:-1]
    attr.append(in4_att)
    value.append(in4_val)
#my_list = [[attr[0], value[0]]]
my_list = [[]]
# df = pd.DataFrame({'attribute': in4_att, 'information': in4_val})
# df.to_csv('./movie_information.csv',index=True)
for i in range(len(my_description)):
    my_list.append([attr[i], value[i]])
df = pd.DataFrame(my_list,columns=['attribute', 'information'])
df.to_csv('./review_movie.csv',index=False)

# %%
#! crawl comment phim
for url in all_movie_link:
    

    page = requests.get(url)

    soup = BeautifulSoup(page.text,'html')
    path = soup.find_all(class_="text")

    my_text = []
    for text in path:
        # in4 = [item.strip() for item in in4 if str(item)]
        a = text.get_text().replace('\n','')
        #print(a)
        my_text.append(a)
# Out:
# []

# %%
my_text
